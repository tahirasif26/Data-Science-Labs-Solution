# %%
import pandas as pd 
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, StratifiedShuffleSplit, RepeatedKFold, train_test_split

# %%
df = pd.read_csv("fertility_Diagnosis.txt")
df
# Out:
#     -0.33  0.69  0  1  1.1  0.1  0.8  0.2  0.88  N
# 0   -0.33  0.94  1  0    1    0  0.8    1  0.31  O
# 1   -0.33  0.50  1  0    0    0  1.0   -1  0.50  N
# 2   -0.33  0.75  0  1    1    0  1.0   -1  0.38  N
# 3   -0.33  0.67  1  1    0    0  0.8   -1  0.50  O
# 4   -0.33  0.67  1  0    1    0  0.8    0  0.50  N
# 5   -0.33  0.67  0  0    0   -1  0.8   -1  0.44  N
# 6   -0.33  1.00  1  1    1    0  0.6   -1  0.38  N
# 7    1.00  0.64  0  0    1    0  0.8   -1  0.25  N
# 8    1.00  0.61  1  0    0    0  1.0   -1  0.25  N
# 9    1.00  0.67  1  1    0   -1  0.8    0  0.31  N
# 10   1.00  0.78  1  1    1    0  0.6    0  0.13  N
# 11   1.00  0.75  1  1    1    0  0.8    1  0.25  N
# 12   1.00  0.81  1  0    0    0  1.0   -1  0.38  N
# 13   1.00  0.94  1  1    1    0  0.2   -1  0.25  N
# 14   1.00  0.81  1  1    0    0  1.0    1  0.50  N
# 15   1.00  0.64  1  0    1    0  1.0   -1  0.38  N
# 16   1.00  0.69  1  0    1    0  0.8   -1  0.25  O
# 17   1.00  0.75  1  1    1    0  1.0    1  0.25  N
# 18   1.00  0.67  1  0    0    0  0.8    1  0.38  O
# 19   1.00  0.67  0  0    1    0  0.8   -1  0.25  N
# 20   1.00  0.75  1  0    0    0  0.6    0  0.25  N
# 21   1.00  0.67  1  1    0    0  0.8   -1  0.25  N
# 22   1.00  0.69  1  0    1   -1  1.0   -1  0.44  O
# 23   1.00  0.56  1  0    1    0  1.0   -1  0.63  N
# 24   1.00  0.67  1  0    0    0  1.0   -1  0.25  N
# 25   1.00  0.67  1  0    1    0  0.6   -1  0.38  O
# 26   1.00  0.78  1  1    0    1  0.6   -1  0.38  O
# 27   1.00  0.58  0  0    1    0  1.0   -1  0.19  N
# 28   1.00  0.67  0  0    1    0  0.6    0  0.50  O
# 29   1.00  0.61  1  0    1    0  1.0   -1  0.63  N
# ..    ...   ... .. ..  ...  ...  ...  ...   ... ..
# 69  -0.33  0.50  1  1    0   -1  0.8    0  0.88  O
# 70   0.33  0.69  1  0    0    1  1.0   -1  0.31  N
# 71   1.00  0.56  1  0    0    1  0.6    0  0.50  N
# 72  -1.00  0.50  1  0    0    1  0.8   -1  0.44  N
# 73  -1.00  0.53  1  0    0    1  0.8   -1  0.63  N
# 74  -1.00  0.78  1  0    1    1  1.0    1  0.25  N
# 75  -1.00  0.75  1  0    1    1  0.6    0  0.56  N
# 76  -1.00  0.72  1  1    1    1  0.8   -1  0.19  N
# 77  -1.00  0.53  1  1    0    1  0.8   -1  0.38  N
# 78  -1.00  1.00  1  0    1    1  0.6    0  0.25  N
# 79  -0.33  0.92  1  1    0    1  1.0   -1  0.63  N
# 80  -1.00  0.81  1  1    1    1  0.8    0  0.19  N
# 81  -0.33  0.92  1  0    0    1  0.6   -1  0.19  N
# 82  -0.33  0.86  1  1    1    1  1.0   -1  0.25  N
# 83  -0.33  0.78  1  0    0    1  1.0    1  0.06  O
# 84  -0.33  0.89  1  1    0    0  0.6    1  0.31  N
# 85  -0.33  0.75  1  1    1    0  0.6    1  0.25  N
# 86  -0.33  0.75  1  1    1    1  0.8    1  0.25  N
# 87  -0.33  0.83  1  1    1    0  1.0   -1  0.31  N
# 88  -0.33  0.81  1  1    1    0  1.0    1  0.38  N
# 89  -0.33  0.81  1  1    1    1  0.8   -1  0.38  N
# 90   0.33  0.78  1  0    0    0  1.0    1  0.06  N
# 91   0.33  0.75  1  1    0    0  0.8   -1  0.38  N
# 92   0.33  0.75  1  0    1    0  0.8   -1  0.44  O
# 93   1.00  0.58  1  0    0    0  0.6    1  0.50  N
# 94  -1.00  0.67  1  0    0    0  1.0   -1  0.50  N
# 95  -1.00  0.61  1  0    0    0  0.8    0  0.50  N
# 96  -1.00  0.67  1  1    1    0  1.0   -1  0.31  N
# 97  -1.00  0.64  1  0    1    0  1.0    0  0.19  N
# 98  -1.00  0.69  0  1    1    0  0.6   -1  0.19  N
#
# [99 rows x 10 columns]

# %%
array = df.values
X = array[:,0:9]
Y = array[:,9]

# %%
# DT using gini(without puring)
Gini = DecisionTreeClassifier( criterion='gini' )

# %%
CV = RepeatedKFold(n_splits = 10, n_repeats = 10, random_state = 1)

# %%
CV2 = StratifiedShuffleSplit(n_splits=100, test_size=0.3, random_state=0)

# %%
Acc_n_Std = cross_val_score(Gini, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', np.mean(Acc_n_Std), ' Standard Deviation: ', np.std(Acc_n_Std))
# Out:
# Accuracy:  0.7825555555555556  Standard Deviation:  0.11606995549194132

# %%
Acc_n_Std = cross_val_score(Gini, X, Y, scoring='accuracy', cv=CV2, n_jobs = -1)
print('Accuracy: ', np.mean(Acc_n_Std), ' Standard Deviation: ', np.std(Acc_n_Std))
# Out:
# Accuracy:  0.7899999999999997  Standard Deviation:  0.055677643628300244

# %%
# DT using Gini(With Puring)
Gini_P = DecisionTreeClassifier( criterion='gini', ccp_alpha = 0.015)

# %%
CV = RepeatedKFold(n_splits = 10, n_repeats = 10, random_state = 1)

# %%
CV2 = StratifiedShuffleSplit(n_splits=100, test_size=0.3, random_state=0)

# %%
Acc_n_Std = cross_val_score(Gini, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', np.mean(Acc_n_Std), ' Standard Deviation: ', np.std(Acc_n_Std))
# Out:
# Accuracy:  0.9973105265262865  Standard Deviation:  0.002019946149391974

# %%
Acc_n_Std = cross_val_score(Gini, X, Y, scoring='accuracy', cv=CV2, n_jobs = -1)
print('Accuracy: ', np.mean(Acc_n_Std), ' Standard Deviation: ', np.std(Acc_n_Std))
# Out:
# Accuracy:  0.9970110701107011  Standard Deviation:  0.0013828071095805812

# %%
# DT using Entropy(without puring) 
Entropy = DecisionTreeClassifier( criterion='entropy' )

# %%
CV = RepeatedKFold(n_splits = 10, n_repeats = 10, random_state = 1)

# %%
CV2 = StratifiedShuffleSplit(n_splits=100, test_size=0.3, random_state=0)

# %%
Acc_n_Std = cross_val_score(Entropy, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', np.mean(Acc_n_Std), ' Standard Deviation: ', np.std(Acc_n_Std))
# Out:
# Accuracy:  0.9973262243285942  Standard Deviation:  0.0021074325634023237

# %%
Acc_n_Std = cross_val_score(Entropy, X, Y, scoring='accuracy', cv=CV2, n_jobs = -1)
print('Accuracy: ', np.mean(Acc_n_Std), ' Standard Deviation: ', np.std(Acc_n_Std))
# Out:
# Accuracy:  0.9972113863995783  Standard Deviation:  0.0012810784146579607

# %%
# DT using Entropy(with Puring)
Entropy_P = DecisionTreeClassifier( criterion='entropy', ccp_alpha = 0.015)

# %%
CV = RepeatedKFold(n_splits = 10, n_repeats = 10, random_state = 1)

# %%
CV2 = StratifiedShuffleSplit(n_splits=100, test_size=0.3, random_state=0)

# %%
Acc_n_Std = cross_val_score(Entropy, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', np.mean(Acc_n_Std), ' Standard Deviation: ', np.std(Acc_n_Std))
# Out:
# Accuracy:  0.9974211360409544  Standard Deviation:  0.002058853714516901

# %%
Acc_n_Std = cross_val_score(Entropy, X, Y, scoring='accuracy', cv=CV2, n_jobs = -1)
print('Accuracy: ', np.mean(Acc_n_Std), ' Standard Deviation: ', np.std(Acc_n_Std))
# Out:
# Accuracy:  0.9972482867685821  Standard Deviation:  0.0013410300270991177
